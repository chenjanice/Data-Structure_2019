# %% [markdown]
# # Dijkstra's algorithm(Single Source Shortest Paths)
#
# ### 簡介
# - 每次新擴展一個距離最短的點，更新與其相鄰的點的距離。
# - 當所有邊權都為正時，由於不會存在一個距離更短的沒擴展過的點，所以這個點的距離永遠不會再被改變，因而保證了演算法的正確性。
# - 不能有負權邊，因為擴展到負權邊的時候會產生更短的距離，有可能就破壞了已經更新的點距離不會改變的性質。
#
# ### 舉例
# 如果圖中的頂點表示城市，而邊上的權重表示著城市間開車行經的距離。 Dijkstra演算法可以用來找到兩個城市之間的最短路徑。
# ![image](https://wiki.mbalib.com/w/images/6/65/Dijkstra%E7%AE%97%E6%B3%95%E5%9B%BE.jpg)
#
# ### 作法
#
# 1. 頂點放入群組
# 2. 把頂點的cost放入matrix：第一步驟
#
#
# 3. 找到最小值
# 4. 將最小值放入群組
# 5. 群組內的cost直接貼上
# 6. 群組外飛0的cost一一比對
#
#
#
# 7. 重複3-6 直到結束
#
# ### 參考資料
# * [Dijkstra演算法 - MBA智库百科](https://wiki.mbalib.com/zh-tw/Dijkstra%E7%AE%97%E6%B3%95)
# * [戴克斯特拉算法 - 維基百科，自由的百科全書](https://zh.wikipedia.org/wiki/%E6%88%B4%E5%85%8B%E6%96%AF%E7%89%B9%E6%8B%89%E7%AE%97%E6%B3%95)
# * [代克思托演算法 (Dijkstra's algorithm)](http://nthucad.cs.nthu.edu.tw/~yyliu/personal/nou/04ds/dijkstra.html)
#
# -----------------------------------------------------

# %% [markdown]
# # Kruskal's algorithm(找Minimum Spanning Tree)
#
# ### 簡介
# - Kruskal 演算法是一種用來尋找 MST(minimum spanning tree) 的演算法
# - 依次找尋圖形中加權值最小的邊加入spanning tree，嘗試連結圖的N個頂點，但不使用會造成圖形成環路的邊，直到產生N-1個邊。
# - **生成樹Spanning Tree**：
#    - 一棵【包含圖上所有點】的樹，稱作該圖的生成樹
#    - 一張圖的生成樹可能會有很多種
#    - 完全連通圖才有生成樹 (不連通時，則稱為生成森林)
#    - 生成樹的權重為樹上每條邊的權重總和
# - **最小生成樹Minimum Spanning Tree**：擁有最小權重的生成樹，稱為最小生成樹
#
# ### 舉例
# ![image](http://wiki.csie.ncku.edu.tw/acm/MST_Kruskal.gif)
#
# ### 作法
#
# 1. 將所有的邊，依照權重的大小排序。
# 2. 依序加入權重最小的邊，如果造成cycle時，則必須捨棄。
# 3. 直到增加了n - 1條邊為止。(假設有 n 個節點)
#
#
# ### 參考資料
# * [克魯斯克爾演算法 - 維基百科，自由的百科全書](https://zh.wikipedia.org/wiki/%E5%85%8B%E9%B2%81%E6%96%AF%E5%85%8B%E5%B0%94%E6%BC%94%E7%AE%97%E6%B3%95)
# * [Wiki - acm/course/MST](http://wiki.csie.ncku.edu.tw/acm/course/MST)
# * [克魯斯克爾演算法 (Kruskal's algorithm)](http://nthucad.cs.nthu.edu.tw/~yyliu/personal/nou/04ds/kruskal.html)
#
# -----------------------------------------------------

# %% [markdown]
# # Dijkstra's algorithm
# **標準格式**

# %%
# Python program for Dijkstra's single  
# source shortest path algorithm. The program is  
# for adjacency matrix representation of the graph 
# Python program for Kruskal's algorithm to find 
# Minimum Spanning Tree of a given connected,  
# undirected and weighted graph 

from collections import defaultdict 

#Class to represent a graph 
class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [
            [ '-' for column in range(vertices )]  
                    for row in range(vertices )] 
    def addEdge(self,u,v,w): 
        """
        :type u,v,w: int
        :rtype: None
        """
    def Dijkstra(self, s): 
        """
        :type s: int
        :rtype: dict
        """
    def Kruskal(self):
        """
        :rtype: dict
        """

# %% [markdown]
# **第一步：**先玩玩看、試著理解助教給的程式碼是什麼意思

# %%
g = Graph(9)
g.graph = [
    [0,4,0,0,0,0,0,8,0],
    [4,0,8,0,0,0,0,11,0],
    [0,8,0,7,0,4,0,0,2],
    [0,0,7,0,9,14,0,0,0],
    [0,0,0,9,0,10,0,0,0],
    [0,0,4,14,10,0,2,0,0],
    [0,0,0,0,0,2,0,1,6],
    [8,11,0,0,0,0,1,0,7],
    [0,0,2,0,0,0,6,7,0]
];

# %%
print("Dijkstra",g.Dijkstra(0))

g=Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print("Kruskal",g.Kruskal())

# %%
print(g.graph)
# Out:
# [[0, 4, 0, 0, 0, 0, 0, 8, 0], [4, 0, 8, 0, 0, 0, 0, 11, 0], [0, 8, 0, 7, 0, 4, 0, 0, 2], [0, 0, 7, 0, 9, 14, 0, 0, 0], [0, 0, 0, 9, 0, 10, 0, 0, 0], [0, 0, 4, 14, 10, 0, 2, 0, 0], [0, 0, 0, 0, 0, 2, 0, 1, 6], [8, 11, 0, 0, 0, 0, 1, 0, 7], [0, 0, 2, 0, 0, 0, 6, 7, 0]]

# %%
print(g.graph_matrix)
# Out:
# [['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-']]

# %% [markdown]
# 以上為9x9的矩陣

# %% [markdown]
# **簡化格式**

# %%
from collections import defaultdict 
class Graph(): 
    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [
            [- for column in range(vertices )]  
                    for row in range(vertices )] 
        
    def Dijkstra(self, s):
        g.graph[s]

# %% [markdown]
# **第二步：**把每一個步驟釐清
#
#
# 1. 頂點放入群組
# 2. 把頂點的cost放入matrix：第一步驟
# ----
# 3. 找到最小值
# 4. 將最小值放入群組
# 5. 群組內的cost直接貼上
# 6. 群組外飛0的cost一一比對
# ----
# 7. 重複3-6 直到結束

# %%
gg=[[0, 4, 0, 0, 0, 0, 0, 8, 0], 
     [4, 0, 8, 0, 0, 0, 0, 11, 0], 
     [0, 8, 0, 7, 0, 4, 0, 0, 2],
     [0, 0, 7, 0, 9, 14, 0, 0, 0],
     [0, 0, 0, 9, 0, 10, 0, 0, 0],
     [0, 0, 4, 14, 10, 0, 2, 0, 0],
     [0, 0, 0, 0, 0, 2, 0, 1, 6], 
     [8, 11, 0, 0, 0, 0, 1, 0, 7],
     [0, 0, 2, 0, 0, 0, 6, 7, 0]]

matrix=[['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-']]

def findmin(step,group):
    temp=[]
    for i in range(9):
        if (i in group) or (matrix[step][i]=='-'):
            temp.append(1000000000000)
        else:
            temp.append(matrix[step][i])
    
    return min(temp),temp.index(min(temp))

def paste(step,group):
    global matrix
    for i in range(9):
        if i in group:
            matrix[step][i]=matrix[step-1][i]
    return matrix


def upgrade(step,group):
    top=group[0]
    point=group[-1]

    for i in range(9):
        if (i not in group) and (gg[point][i]!=0):
            num=gg[top][point]+gg[point][i]
            if matrix[step-1][i]=='-':
                matrix[step][i]=num
            elif matrix[step-1][i] > num:
                matrix[step][i]=num
            elif matrix[step-1][i] <num:
                matrix[step][i]=matrix[step-1][i]
    return matrix


#預設頂點為 x
def Dijkstra(x):
    global matrix
    #把頂點加入群組
    group=[]
    group.append(x)
    
    #matrix第一步驟：把頂點的鄰點、cost放入 matrix作為第一步
    #group=[0]
    matrix[0][x]=0
    for i in range(9):
        if gg[x][i] !=0:
            matrix[0][i]=gg[x][i]
    
    #matrix第二步驟：找到matrix第一步的最小值、放入群組
    #group=[0,1]
    cost,point=findmin(0,group)
    group.append(point)
    
    #把群組已有的point複製到此步驟
    matrix=paste(1,group)
    print(matrix)
    print()
    
    #新增的點[1]的cost一一比對
    matrix=upgrade(1,group)
    print(matrix)
    print()
    
    #matrix第三步驟：找到matrix第一步的最小值、放入群組
    #group=[0,1,7]
    cost,point=findmin(1,group)
    print(cost,point)
    group.append(point)
    
    #把群組已有的point複製到此步驟
    matrix=paste(2,group)
    print(matrix)
    print()
    
    #新增的點[7]的cost一一比對
    matrix=upgrade(2,group)
    print(matrix)
    print()
    

Dijkstra(0)
# Out:
# [[0, 4, '-', '-', '-', '-', '-', 8, '-'], [0, 4, '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-']]
#
# [[0, 4, '-', '-', '-', '-', '-', 8, '-'], [0, 4, 12, '-', '-', '-', '-', 8, '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-']]
#
# 8 7
# ...

# %% [markdown]
# 前三步驟都ok
# **第四部：整理一下順序**

# %%
gg=[[0, 4, 0, 0, 0, 0, 0, 8, 0], 
     [4, 0, 8, 0, 0, 0, 0, 11, 0], 
     [0, 8, 0, 7, 0, 4, 0, 0, 2],
     [0, 0, 7, 0, 9, 14, 0, 0, 0],
     [0, 0, 0, 9, 0, 10, 0, 0, 0],
     [0, 0, 4, 14, 10, 0, 2, 0, 0],
     [0, 0, 0, 0, 0, 2, 0, 1, 6], 
     [8, 11, 0, 0, 0, 0, 1, 0, 7],
     [0, 0, 2, 0, 0, 0, 6, 7, 0]]

matrix=[['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-']]

def findmin(step,group):
    temp=[]
    for i in range(9):
        if (i in group) or (matrix[step][i]=='-'):
            temp.append(1000000000000)
        else:
            temp.append(matrix[step][i])
    
    return min(temp),temp.index(min(temp))

def paste(step,group):
    global matrix
    for i in range(9):
        if i in group:
            matrix[step][i]=matrix[step-1][i]
    return matrix


def upgrade(step,group):
    top=group[0]
    point=group[-1]

    for i in range(9):
        if (i not in group) and (gg[point][i]!=0):
            num=gg[top][point]+gg[point][i]
            if matrix[step-1][i]=='-':
                matrix[step][i]=num
            elif matrix[step-1][i] > num:
                matrix[step][i]=num
            elif matrix[step-1][i] <num:
                matrix[step][i]=matrix[step-1][i]
    return matrix


#預設頂點為 x
def Dijkstra(x):
    global matrix
    #把頂點加入群組
    group=[]
    group.append(x)
    
    #matrix【STEP 0】：把頂點的鄰點、cost放入 matrix
    #group=[0]
    matrix[0][x]=0
    for i in range(9):
        if gg[x][i] !=0:
            matrix[0][i]=gg[x][i]
    
    #找到matrix【STEP 0】的最小值、放入群組
    #group=[0,1]
    cost,point=findmin(0,group)
    group.append(point)

    
    
    #matrix【STEP 1】把群組已有的point複製到此步驟
    matrix=paste(1,group)
    
    #matrix【STEP 1】新增的點[1]的cost一一比對
    matrix=upgrade(1,group)
    
    #找到matrix【STEP 1】的最小值、放入群組
    #group=[0,1,7]
    cost,point=findmin(1,group)
    group.append(point)
    
    
    
    #matrix【STEP 2】把群組已有的point複製到此步驟
    matrix=paste(2,group)
    
    #matrix【STEP 2】新增的點[7]的cost一一比對
    matrix=upgrade(2,group)
    
    #找到matrix【STEP 2】的最小值、放入群組
    #group=[0,1,7,6]
    cost,point=findmin(2,group)
    group.append(point)
    

Dijkstra(0)
# Out:
# [[0, 4, '-', '-', '-', '-', '-', 8, '-'], [0, 4, '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-']]
#
# [[0, 4, '-', '-', '-', '-', '-', 8, '-'], [0, 4, 12, '-', '-', '-', '-', 8, '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-'], ['-', '-', '-', '-', '-', '-', '-', '-', '-']]
#
# 8 7
# ...

# %% [markdown]
# **第五步：換成迴圈**

# %%
gg=[[0, 4, 0, 0, 0, 0, 0, 8, 0], 
     [4, 0, 8, 0, 0, 0, 0, 11, 0], 
     [0, 8, 0, 7, 0, 4, 0, 0, 2],
     [0, 0, 7, 0, 9, 14, 0, 0, 0],
     [0, 0, 0, 9, 0, 10, 0, 0, 0],
     [0, 0, 4, 14, 10, 0, 2, 0, 0],
     [0, 0, 0, 0, 0, 2, 0, 1, 6], 
     [8, 11, 0, 0, 0, 0, 1, 0, 7],
     [0, 0, 2, 0, 0, 0, 6, 7, 0]]

matrix=[['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-'], 
        ['-', '-', '-', '-', '-', '-', '-', '-', '-']]

def findmin(step,group):
    temp=[]
    for i in range(9):
        if (i in group) or (matrix[step][i]=='-'):
            temp.append(1000000000000)
        else:
            temp.append(matrix[step][i])
    
    return min(temp),temp.index(min(temp))

def paste(step,group):
    global matrix
    for i in range(9):
        if i in group:
            matrix[step][i]=matrix[step-1][i]
    return matrix


def upgrade(step,group):
    top=group[0]
    point=group[-1]

    for i in range(9):
        if (i not in group) and (gg[point][i]!=0):
            num=matrix[step-1][point]+gg[point][i]
            if matrix[step-1][i]=='-':
                matrix[step][i]=num
            elif matrix[step-1][i] > num:
                matrix[step][i]=num
            elif matrix[step-1][i] <num:
                matrix[step][i]=matrix[step-1][i]
    return matrix

def down(step):
    for i in range(9):
        if (matrix[step][i]=='-') and (matrix[step-1][i]!='-'):
            matrix[step][i]=matrix[step-1][i]
    return matrix
        


#預設頂點為 x
def Dijkstra(x):
    global matrix
    #把頂點加入群組
    group=[]
    group.append(x)
    
    #matrix【STEP 0】：把頂點的鄰點、cost放入 matrix
    #group=[0]
    matrix[0][x]=0
    for i in range(9):
        if gg[x][i] !=0:
            matrix[0][i]=gg[x][i]
    
    #找到matrix【STEP 0】的最小值、放入群組
    #group=[0,1]
    cost,point=findmin(0,group)
    group.append(point)

    for t in range(1,9):
        #matrix【STEP t】把群組已有的point複製到此步驟
        matrix=paste(t,group)

        #matrix【STEP t】新增的點t的cost一一比對
        matrix=upgrade(t,group)

        #找到matrix【STEP t】的最小值、放入群組
        cost,point=findmin(t,group)
        group.append(point)
        
        #將 不在群組裡、不是新增點的鄰點的cost直接貼上
        matrix=down(t)
    
    print(matrix)
    

Dijkstra(0)
# Out:
# [[0, 4, '-', '-', '-', '-', '-', 8, '-'], [0, 4, 12, '-', '-', '-', '-', 8, '-'], [0, 4, 12, '-', '-', '-', 9, 8, 15], [0, 4, 12, '-', '-', 11, 9, 8, 15], [0, 4, 12, 25, 21, 11, 9, 8, 15], [0, 4, 12, 19, 21, 11, 9, 8, 14], [0, 4, 12, 19, 21, 11, 9, 8, 14], [0, 4, 12, 19, 21, 11, 9, 8, 14], [0, 4, 12, 19, 21, 11, 9, 8, 14]]

# %% [markdown]
# **第六步：把答案轉成dictionary**

# %%
from collections import defaultdict 
class Graph(): 
    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [
            ["-" for column in range(vertices)]  
                    for row in range(vertices)] 
        self.group=[]
    

    def findmin(self,step):
        temp=[]
        for i in range(self.V):
            if (i in self.group) or (self.graph_matrix[step][i]=='-'):
                temp.append(1000000000000)
            else:
                temp.append(self.graph_matrix[step][i])

        return min(temp),temp.index(min(temp))

    def paste(self,step):
        for i in range(self.V):
            if i in self.group:
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix


    def upgrade(self,step):
        top=self.group[0]
        point=self.group[-1]

        for i in range(self.V):
            if (i not in self.group) and (self.graph[point][i]!=0):
                num=self.graph_matrix[step-1][point]+self.graph[point][i]
                if self.graph_matrix[step-1][i]=='-':
                    self.graph_matrix[step][i]=num
                elif self.graph_matrix[step-1][i] > num:
                    self.graph_matrix[step][i]=num
                elif self.graph_matrix[step-1][i] <num:
                    self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
            elif (i not in self.group) and self.graph_matrix[point][i]!=0:
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix

    def down(self,step):
        for i in range(self.V):
            if (self.graph_matrix[step][i]=='-') and (self.graph_matrix[step-1][i]!='-'):
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix
    
    def to_dic(self):
        temp=self.graph_matrix[-1]
        d=dict()
        for i in range(len(temp)):
            d[i]=temp[i]
        return d


    def Dijkstra(self, s):
        self.group.clear()
        self.graph_matrix.clear()
        self.graph_matrix = [
            ["-" for column in range(self.V)]  
                    for row in range(self.V)]         
        #把頂點加入群組
        self.group.append(s)

        #matrix【STEP 0】：把頂點的鄰點、cost放入 matrix
        #group=[0]
        self.graph_matrix[0][s]=0
        for i in range(self.V):
            if self.graph[s][i] !=0:
                self.graph_matrix[0][i]=self.graph[s][i]

        #找到matrix【STEP 0】的最小值、放入群組
        #group=[0,1]
        cost,point=Graph.findmin(self,0)
        self.group.append(point)

        for t in range(1,self.V):
            #matrix【STEP t】把群組已有的point複製到此步驟
            self.graph_matrix=Graph.paste(self,t)

            #matrix【STEP t】新增的點t的cost一一比對
            self.graph_matrix=Graph.upgrade(self,t)

            #找到matrix【STEP t】的最小值、放入群組
            cost,point=Graph.findmin(self,t)
            self.group.append(point)

            #將 不在群組裡、不是新增點的鄰點的cost直接貼上
            self.graph_matrix=Graph.down(self,t)

        #print(self.graph_matrix)
        d=Graph.to_dic(self)
        return d
    



g = Graph(9)
g.graph = [
    [0,4,0,0,0,0,0,8,0],
    [4,0,8,0,0,0,0,11,0],
    [0,8,0,7,0,4,0,0,2],
    [0,0,7,0,9,14,0,0,0],
    [0,0,0,9,0,10,0,0,0],
    [0,0,4,14,10,0,2,0,0],
    [0,0,0,0,0,2,0,1,6],
    [8,11,0,0,0,0,1,0,7],
    [0,0,2,0,0,0,6,7,0]
];

print("Dijkstra",g.Dijkstra(0))
print("Dijkstra",g.Dijkstra(1))
print("Dijkstra",g.Dijkstra(2))
print("Dijkstra",g.Dijkstra(3))
print("Dijkstra",g.Dijkstra(4))
print("Dijkstra",g.Dijkstra(5))
print("Dijkstra",g.Dijkstra(6))
print("Dijkstra",g.Dijkstra(7))
print("Dijkstra",g.Dijkstra(8))
# Out:
# Dijkstra {0: 0, 1: 4, 2: 12, 3: 19, 4: 21, 5: 11, 6: 9, 7: 8, 8: 14}
# Dijkstra {0: 4, 1: 0, 2: 8, 3: 15, 4: 22, 5: 12, 6: 12, 7: 11, 8: 10}
# Dijkstra {0: 12, 1: 8, 2: 0, 3: 7, 4: 14, 5: 4, 6: 6, 7: 7, 8: 2}
# Dijkstra {0: 19, 1: 15, 2: 7, 3: 0, 4: 9, 5: 11, 6: 13, 7: 14, 8: 9}
# Dijkstra {0: 21, 1: 22, 2: 14, 3: 9, 4: 0, 5: 10, 6: 12, 7: 13, 8: 16}
# Dijkstra {0: 11, 1: 12, 2: 4, 3: 11, 4: 10, 5: 0, 6: 2, 7: 3, 8: 6}
# Dijkstra {0: 9, 1: 12, 2: 6, 3: 13, 4: 12, 5: 2, 6: 0, 7: 1, 8: 6}
# Dijkstra {0: 8, 1: 11, 2: 7, 3: 14, 4: 13, 5: 3, 6: 1, 7: 0, 8: 7}
# Dijkstra {0: 14, 1: 10, 2: 2, 3: 9, 4: 16, 5: 6, 6: 6, 7: 7, 8: 0}

# %% [markdown]
# # Kruskal's algorithm

# %% [markdown]
# **第一步：init中新增.graph1(方便和Dijkstra區別) 和.weight(方便找最小值)**

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.graph1 = defaultdict(list)
        self.weight = []
        self.head = defaultdict(list)
    def addEdge(self,u,v,w): 
        self.graph1[w].append(u)
        self.graph1[w].append(v)
        self.weight.append(w)
        self.head[u]= -1
        self.head[v]= -1
    def Kruskal(self):
        ''''''

# %%
g=Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

#print("Kruskal",g.Kruskal())

print(g.graph1)
print(g.weight)
print(g.head)
# Out:
# defaultdict(<class 'list'>, {10: [0, 1], 6: [0, 2], 5: [0, 3], 15: [1, 3], 4: [2, 3]})
# [10, 6, 5, 15, 4]
# defaultdict(<class 'list'>, {0: -1, 1: -1, 2: -1, 3: -1})

# %% [markdown]
# **第二步：試寫將最低權重的點到點，輸出成答案要的格式**

# %%
weight=[10, 6, 5, 15, 4]
graph1={10: [0, 1], 6: [0, 2], 5: [0, 3], 15: [1, 3], 4: [2, 3]}
answer=dict()

#找到權重最小的weight
x=min(weight)
weight.pop(x)

#找到權重的'點-點'
a,b=graph1[x]
key='%s-%s'%(a,b)

#存成字典
answer[key]=x
print(answer)
print(weight)
# Out:
# {'2-3': 4}
# [10, 6, 5, 15]

# %% [markdown]
# **第三步：檢查是否形成迴圈**
# self.head = defaultdict(list)
# self.head[u]= -1
# self.head[v]= -1
#
# - 情況：
#   1. 皆為-1
#   2. 一個-1、一個x
#   3. 皆為x =>【迴圈】
#   4. 一個x、一個y =>【兩棵樹合併】

# %%
def check(a,b):
    if (head[a] == -1) and (head[b] == -1):
        head[a]=a
        head[b]=a
        return True
    elif (head[a] == -1) and (head[b] != -1):
        head[a]=head[b]
        return True
    elif (head[a] != -1) and (head[b] == -1):
        head[b]=head[a]
        return True
    elif (head[a] != -1) and (head[b] != -1) and (head[a] == head[b]):
        return False
    elif (head[a] != -1) and (head[b] != -1) and (head[a] != head[b]):
        for k in head:
            if head[k]==head[b]:
                head[k]=head[a]
        return True


weight=[10, 6, 5, 15, 4]
graph1={10: [0, 1], 6: [0, 2], 5: [0, 3], 15: [1, 3], 4: [2, 3]}
answer=dict()
head= {0: -1, 1: -1, 2: -1, 3: -1}

#找到權重最小的weight
x=min(weight)
weight.pop(weight.index(x))
print(x)
#找到權重的'點-點'
a,b=graph1[x]
key='%s-%s'%(a,b)

#更改head
head[a]=a
head[b]=a

#存成字典
answer[key]=x
print(answer)
print(weight)
print(head)
print('===')


#---第二次
x=min(weight)
print(x)
a,b=graph1[x]

#檢查迴圈 & 改head
if check(a,b):
    key='%s-%s'%(a,b)
    answer[key]=x
weight.pop(weight.index(x))
print(answer)
print(weight)
print(head)
# Out:
# 4
# {'2-3': 4}
# [10, 6, 5, 15]
# {0: -1, 1: -1, 2: 2, 3: 2}
# ===
# 5
# {'2-3': 4, '0-3': 5}
# [10, 6, 15]
# {0: 2, 1: -1, 2: 2, 3: 2}

# %% [markdown]
# **第四步：寫成迴圈**

# %%
weight=[10, 6, 5, 15, 4]
graph1={10: [0, 1], 6: [0, 2], 5: [0, 3], 15: [1, 3], 4: [2, 3]}
answer=dict()
head= {0: -1, 1: -1, 2: -1, 3: -1}
def check(a,b):
    if (head[a] == -1) and (head[b] == -1):
        head[a]=a
        head[b]=a
        return True
    elif (head[a] == -1) and (head[b] != -1):
        head[a]=head[b]
        return True
    elif (head[a] != -1) and (head[b] == -1):
        head[b]=head[a]
        return True
    elif (head[a] != -1) and (head[b] != -1) and (head[a] == head[b]):
        return False
    elif (head[a] != -1) and (head[b] != -1) and (head[a] != head[b]):
        for k in head:
            if head[k]==head[b]:
                head[k]=head[a]
        return True

def countkey(dic):
    count=0
    for k in dic:
        count+=1
    return count
    

e=0
v=countkey(head)

while e != v-1:

    #找到權重最小的weight
    x=min(weight)
    print(x)
    
    #找到權重的'點-點'
    a,b=graph1[x]
    key='%s-%s'%(a,b)
    
    if check(a,b):
        key='%s-%s'%(a,b)
        answer[key]=x
        e+=1
    weight.pop(weight.index(x))
    print(answer)
    print(weight)
    print(head)
    print('===')
# Out:
# 4
# {'2-3': 4}
# [10, 6, 5, 15]
# {0: -1, 1: -1, 2: 2, 3: 2}
# ===
# 5
# {'2-3': 4, '0-3': 5}
# [10, 6, 15]
# {0: 2, 1: -1, 2: 2, 3: 2}
# ===
# 6
# {'2-3': 4, '0-3': 5}
# [10, 15]
# {0: 2, 1: -1, 2: 2, 3: 2}
# ===
# 10
# {'2-3': 4, '0-3': 5, '0-1': 10}
# [15]
# {0: 2, 1: 2, 2: 2, 3: 2}
# ===

# %% [markdown]
# **ok**

# %% [markdown]
# **第四步：整理格式**

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices
        self.graph1 = defaultdict(list)
        self.weight = []
        self.head = defaultdict(list)
        self.answer=dict()
    def addEdge(self,u,v,w): 
        self.graph1[w].append(u)
        self.graph1[w].append(v)
        self.weight.append(w)
        self.head[u]= -1
        self.head[v]= -1
    def check(self,a,b):
        if (self.head[a] == -1) and (self.head[b] == -1):
            self.head[a]=a
            self.head[b]=a
            return True
        elif (self.head[a] == -1) and (self.head[b] != -1):
            self.head[a]=self.head[b]
            return True
        elif (self.head[a] != -1) and (self.head[b] == -1):
            self.head[b]=self.head[a]
            return True
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] == self.head[b]):
            return False
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] != self.head[b]):
            for k in self.head:
                if self.head[k]==self.head[b]:
                    self.head[k]=self.head[a]
            return True

    def Kruskal(self):
        e=0
        v=self.V
        
        while e != v-1:
            x=min(self.weight)
            a,b=self.graph1[x]
            key='%s-%s'%(a,b)

            if Graph.check(self,a,b):
                key='%s-%s'%(a,b)
                self.answer[key]=x
                e+=1
            self.weight.pop(self.weight.index(x)) 
            
        return self.answer

# %%
g=Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print("Kruskal",g.Kruskal())
# Out:
# Kruskal {'2-3': 4, '0-3': 5, '0-1': 10}

# %% [markdown]
# **發現一個問題：如果遇到權重相同怎麼辦?**
#
# 調整：將graph1中，加入answer的內容刪除

# %%
from collections import defaultdict 

class Graph(): 

    def __init__(self, vertices): 
        self.V = vertices
        self.graph1 = defaultdict(list)
        self.weight = []
        self.head = defaultdict(list)
        self.answer=dict()
    def addEdge(self,u,v,w): 
        lst=[u,v]
        self.graph1[w].append(lst)
        self.weight.append(w)
        self.head[u]= -1
        self.head[v]= -1
    def check(self,a,b):
        if (self.head[a] == -1) and (self.head[b] == -1):
            self.head[a]=a
            self.head[b]=a
            return True
        elif (self.head[a] == -1) and (self.head[b] != -1):
            self.head[a]=self.head[b]
            return True
        elif (self.head[a] != -1) and (self.head[b] == -1):
            self.head[b]=self.head[a]
            return True
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] == self.head[b]):
            return False
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] != self.head[b]):
            for k in self.head:
                if self.head[k]==self.head[b]:
                    self.head[k]=self.head[a]
            return True

    def Kruskal(self):
        e=0
        v=self.V
        
        while e != v-1:
            x=min(self.weight)
            print('min： ',x)
            a,b=self.graph1[x][0]
            key='%s-%s'%(a,b)
            print('key： ',key)

            if Graph.check(self,a,b):
                key='%s-%s'%(a,b)
                self.answer[key]=x
                e+=1
            self.weight.pop(self.weight.index(x))
            
            c=self.graph1[x]
            d=self.graph1[x][0]
            self.graph1[x].pop(c.index(d))
            
            print('weight： ',self.weight)
            print('answer： ',self.answer)
            print('head： ',self.head)
            print('===')
            
        return self.answer

# %%
g=Graph(10)
g.addEdge(6,7,1)
g.addEdge(2,3,2)
g.addEdge(3,4,2)
g.addEdge(1,2,3)
g.addEdge(7,8,3)
g.addEdge(2,4,4)
g.addEdge(6,8,4)
g.addEdge(5,6,4)
g.addEdge(5,7,5)
g.addEdge(1,4,6)
g.addEdge(9,5,7)
g.addEdge(3,9,8)
g.addEdge(9,10,8)
g.addEdge(1,10,9)
g.addEdge(2,10,9)
g.addEdge(2,9,9)
g.addEdge(3,5,9)
g.addEdge(4,5,9)
g.addEdge(9,7,9)
g.addEdge(9,8,10)
g.addEdge(10,8,18)
print(g.graph1)
print("Kruskal",g.Kruskal())
# Out:
# defaultdict(<class 'list'>, {1: [[6, 7]], 2: [[2, 3], [3, 4]], 3: [[1, 2], [7, 8]], 4: [[2, 4], [6, 8], [5, 6]], 5: [[5, 7]], 6: [[1, 4]], 7: [[9, 5]], 8: [[3, 9], [9, 10]], 9: [[1, 10], [2, 10], [2, 9], [3, 5], [4, 5], [9, 7]], 10: [[9, 8]], 18: [[10, 8]]})
# min：  1
# key：  6-7
# weight：  [2, 2, 3, 3, 4, 4, 4, 5, 6, 7, 8, 8, 9, 9, 9, 9, 9, 9, 10, 18]
# answer：  {'6-7': 1}
# head：  defaultdict(<class 'list'>, {6: 6, 7: 6, 2: -1, 3: -1, 4: -1, 1: -1, 8: -1, 5: -1, 9: -1, 10: -1})
# ===
# min：  2
# key：  2-3
# weight：  [2, 3, 3, 4, 4, 4, 5, 6, 7, 8, 8, 9, 9, 9, 9, 9, 9, 10, 18]
# answer：  {'6-7': 1, '2-3': 2}
# head：  defaultdict(<class 'list'>, {6: 6, 7: 6, 2: 2, 3: 2, 4: -1, 1: -1, 8: -1, 5: -1, 9: -1, 10: -1})
# ===
# min：  2
# key：  3-4
# weight：  [3, 3, 4, 4, 4, 5, 6, 7, 8, 8, 9, 9, 9, 9, 9, 9, 10, 18]
# answer：  {'6-7': 1, '2-3': 2, '3-4': 2}
# head：  defaultdict(<class 'list'>, {6: 6, 7: 6, 2: 2, 3: 2, 4: 2, 1: -1, 8: -1, 5: -1, 9: -1, 10: -1})
# ===
# min：  3
# key：  1-2
# ...

# %% [markdown]
# # **合併**

# %%
from collections import defaultdict 
class Graph(): 
    def __init__(self, vertices): 
        self.V = vertices 
        self.graph = [] 
        self.graph_matrix = [
            ["-" for column in range(vertices)]  
                    for row in range(vertices)] 
        self.group=[]
        
        self.graph1 = defaultdict(list)
        self.weight = []
        self.head = defaultdict(list)
        self.answer=dict()
    

    def findmin(self,step):
        temp=[]
        for i in range(self.V):
            if (i in self.group) or (self.graph_matrix[step][i]=='-'):
                temp.append(1000000000000)
            else:
                temp.append(self.graph_matrix[step][i])

        return min(temp),temp.index(min(temp))

    def paste(self,step):
        for i in range(self.V):
            if i in self.group:
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix


    def upgrade(self,step):
        top=self.group[0]
        point=self.group[-1]

        for i in range(self.V):
            if (i not in self.group) and (self.graph[point][i]!=0):
                num=self.graph_matrix[step-1][point]+self.graph[point][i]
                if self.graph_matrix[step-1][i]=='-':
                    self.graph_matrix[step][i]=num
                elif self.graph_matrix[step-1][i] > num:
                    self.graph_matrix[step][i]=num
                elif self.graph_matrix[step-1][i] <num:
                    self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
            elif (i not in self.group) and self.graph_matrix[point][i]!=0:
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix

    def down(self,step):
        for i in range(self.V):
            if (self.graph_matrix[step][i]=='-') and (self.graph_matrix[step-1][i]!='-'):
                self.graph_matrix[step][i]=self.graph_matrix[step-1][i]
        return self.graph_matrix
    
    def to_dic(self):
        temp=self.graph_matrix[-1]
        d=dict()
        for i in range(len(temp)):
            d[str(i)]=temp[i]
        return d


    def Dijkstra(self, s):
        self.group.clear()
        self.graph_matrix.clear()
        self.graph_matrix = [
            ["-" for column in range(self.V)]  
                    for row in range(self.V)]         
        self.group.append(s)
        self.graph_matrix[0][s]=0
        for i in range(self.V):
            if self.graph[s][i] !=0:
                self.graph_matrix[0][i]=self.graph[s][i]

        cost,point=Graph.findmin(self,0)
        self.group.append(point)

        for t in range(1,self.V):
            self.graph_matrix=Graph.paste(self,t)
            self.graph_matrix=Graph.upgrade(self,t)
            cost,point=Graph.findmin(self,t)
            self.group.append(point)
            self.graph_matrix=Graph.down(self,t)
        d=Graph.to_dic(self)
        return d
    
    
    

    def addEdge(self,u,v,w): 
        lst=[u,v]
        self.graph1[w].append(lst)
        self.weight.append(w)
        self.head[u]= -1
        self.head[v]= -1
    def check(self,a,b):
        if (self.head[a] == -1) and (self.head[b] == -1):
            self.head[a]=a
            self.head[b]=a
            return True
        elif (self.head[a] == -1) and (self.head[b] != -1):
            self.head[a]=self.head[b]
            return True
        elif (self.head[a] != -1) and (self.head[b] == -1):
            self.head[b]=self.head[a]
            return True
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] == self.head[b]):
            return False
        elif (self.head[a] != -1) and (self.head[b] != -1) and (self.head[a] != self.head[b]):
            for k in self.head:
                if self.head[k]==self.head[b]:
                    self.head[k]=self.head[a]
            return True

    def Kruskal(self):
        e=0
        v=self.V
        
        while e != v-1:
            x=min(self.weight)
            a,b=self.graph1[x][0]
            key='%s-%s'%(a,b)
            if Graph.check(self,a,b):
                key='%s-%s'%(a,b)
                self.answer[key]=x
                e+=1
            self.weight.pop(self.weight.index(x))
            c=self.graph1[x]
            d=self.graph1[x][0]
            self.graph1[x].pop(c.index(d))            
        return self.answer

# %%
g = Graph(9)
g.graph = [
    [0,4,0,0,0,0,0,8,0],
    [4,0,8,0,0,0,0,11,0],
    [0,8,0,7,0,4,0,0,2],
    [0,0,7,0,9,14,0,0,0],
    [0,0,0,9,0,10,0,0,0],
    [0,0,4,14,10,0,2,0,0],
    [0,0,0,0,0,2,0,1,6],
    [8,11,0,0,0,0,1,0,7],
    [0,0,2,0,0,0,6,7,0]
];

print("Dijkstra",g.Dijkstra(0))
print("Dijkstra",g.Dijkstra(1))
print("Dijkstra",g.Dijkstra(2))
print("Dijkstra",g.Dijkstra(3))
print("Dijkstra",g.Dijkstra(4))
print("Dijkstra",g.Dijkstra(5))
print("Dijkstra",g.Dijkstra(6))
print("Dijkstra",g.Dijkstra(7))
print("Dijkstra",g.Dijkstra(8))


g=Graph(4)
g.addEdge(0,1,10)
g.addEdge(0,2,6)
g.addEdge(0,3,5)
g.addEdge(1,3,15)
g.addEdge(2,3,4)

print("Kruskal",g.Kruskal())
# Out:
# Dijkstra {'0': 0, '1': 4, '2': 12, '3': 19, '4': 21, '5': 11, '6': 9, '7': 8, '8': 14}
# Dijkstra {'0': 4, '1': 0, '2': 8, '3': 15, '4': 22, '5': 12, '6': 12, '7': 11, '8': 10}
# Dijkstra {'0': 12, '1': 8, '2': 0, '3': 7, '4': 14, '5': 4, '6': 6, '7': 7, '8': 2}
# Dijkstra {'0': 19, '1': 15, '2': 7, '3': 0, '4': 9, '5': 11, '6': 13, '7': 14, '8': 9}
# Dijkstra {'0': 21, '1': 22, '2': 14, '3': 9, '4': 0, '5': 10, '6': 12, '7': 13, '8': 16}
# Dijkstra {'0': 11, '1': 12, '2': 4, '3': 11, '4': 10, '5': 0, '6': 2, '7': 3, '8': 6}
# Dijkstra {'0': 9, '1': 12, '2': 6, '3': 13, '4': 12, '5': 2, '6': 0, '7': 1, '8': 6}
# Dijkstra {'0': 8, '1': 11, '2': 7, '3': 14, '4': 13, '5': 3, '6': 1, '7': 0, '8': 7}
# Dijkstra {'0': 14, '1': 10, '2': 2, '3': 9, '4': 16, '5': 6, '6': 6, '7': 7, '8': 0}
# Kruskal {'2-3': 4, '0-3': 5, '0-1': 10}

# %% [markdown]
# # 流程圖
#
# ![image](https://raw.githubusercontent.com/chenjanice/Data-Structure_2019/master/images/Dijkstra%26Krusdal.jpg)
#
#
# ---BY.自己畫
